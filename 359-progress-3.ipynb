# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient

csvfile = open('temps.csv', 'r')
reader = csv.DictReader( csvfile )
mongo_client=MongoClient() 
db=mongo_client.october_mug_talk
db.segment.drop()
header= [ "year", "month", "day", "week", "temp_2", "temp_1", "average", "actual", "forecast_noaa", "forecast_acc", "forecast_under", "friend"]
#year,month,day,week,temp_2,temp_1,average,actual,forecast_noaa,forecast_acc,forecast_under,friend
for each in reader:
    row={}
    for field in header:
        row[field]=each[field]

    db.segment.insert_one(row)

for x in db.segment.find():
  print(x)
# Out:
# {'_id': ObjectId('5e3b3d0828be8523b1265651'), 'year': '2016', 'month': '1', 'day': '1', 'week': 'Fri', 'temp_2': '45', 'temp_1': '45', 'average': '45.6', 'actual': '45', 'forecast_noaa': '43', 'forecast_acc': '50', 'forecast_under': '44', 'friend': '29'}
# {'_id': ObjectId('5e3b3d0828be8523b1265652'), 'year': '2016', 'month': '1', 'day': '2', 'week': 'Sat', 'temp_2': '44', 'temp_1': '45', 'average': '45.7', 'actual': '44', 'forecast_noaa': '41', 'forecast_acc': '50', 'forecast_under': '44', 'friend': '61'}
# {'_id': ObjectId('5e3b3d0828be8523b1265653'), 'year': '2016', 'month': '1', 'day': '3', 'week': 'Sun', 'temp_2': '45', 'temp_1': '44', 'average': '45.8', 'actual': '41', 'forecast_noaa': '43', 'forecast_acc': '46', 'forecast_under': '47', 'friend': '56'}
# ...

# %%
for x in db.segment.find({'week': 'Sat', 'actual': '49'}):
  print(x)
# Out:
# {'_id': ObjectId('5e3b3d0828be8523b1265675'), 'year': '2016', 'month': '2', 'day': '6', 'week': 'Sat', 'temp_2': '49', 'temp_1': '53', 'average': '49.1', 'actual': '49', 'forecast_noaa': '47', 'forecast_acc': '53', 'forecast_under': '49', 'friend': '56'}
# {'_id': ObjectId('5e3b3d0828be8523b1265790'), 'year': '2016', 'month': '12', 'day': '3', 'week': 'Sat', 'temp_2': '46', 'temp_1': '50', 'average': '47', 'actual': '49', 'forecast_noaa': '42', 'forecast_acc': '52', 'forecast_under': '47', 'friend': '58'}
